# %%
import os
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/diegocmr/bootcamp_ia/main/bootcamp-solicitacoescredito.csv')

# %%
df
# Out:
#       numero_solicitacao             razaoSocial          nomeFantasia  \
# 0                      1  James Richardson-Patel    Alexandra Williams
# 1                      2      Dr. Geoffrey Walsh     Mr. Darren Arnold
# 2                      3           Joanna Hudson        Dr. David Rees
# 3                      4    Gordon Jones-Hopkins      Sara Reid-Robson
# 4                      5               Nigel Lee    Dr. Stanley Duncan
# ...                  ...                     ...                   ...
# 8968                9041           Leah Williams         Georgia Booth
# 8969                9042      Mr. Jordan Stevens      Miss Ellie Kelly
# 8970                9043         Mr. Barry Wells       Danielle Hudson
# 8971                9044             Keith Jones  Steven Kennedy-Jones
# 8972                9045          Cheryl Johnson  Chelsea Kay-Sinclair
#
#             cnpjSemTraco  maiorAtraso  margemBrutaAcumulada  \
# ...

# %%
df.shape
# Out:
# (8973, 38)

# %%
dict_quebra = {}
for col in df.columns:
    unicos = df[col].unique()
    len_unicos = len(unicos)
    if len_unicos <= 10:
        for unico in unicos:
            df[df[col]==unico].to_csv(col+'_'+str(unico)+'.csv')

# %%
for col in dict_quebra:
    print (col)
    for dataframe in dict_quebra[item]:
        dataframe.to_csv('analises_clusters/'+col+'_'+dataframe[col].unique()+'.csv')

# %%
matriz = []
lista_colunas = []
for item in os.listdir(os.getcwd()):
    if item.split('.')[-1]=='csv':
        sub_matriz = [item]
        df = pd.read_csv(item)
        for col in df.columns:
            if df.dtypes[col] != 'object':
                lista_colunas.append(col)
                sub_matriz.append(df[col].mean())
        matriz.append(sub_matriz)
matriz = pd.DataFrame(matriz)
matriz.columns = lista_colunas[0:32]
matriz.to_csv('analises_clusters/analise_inicial.csv')

# %%
df.dtypes['numero_solicitacao'] == 'int64'
# Out:
# True

# %%
#colunas categoricas < 10 unicos
percentualProtestos
status
definicaoRisco
intervaloFundacao
restricoes
empresa_MeEppMei

# %%
df.groupby(by = col).count()
# Out:
#                     razaoSocial  nomeFantasia  cnpjSemTraco  maiorAtraso  \
# numero_solicitacao
# 1                             1             1             1            1
# 2                             1             1             1            1
# 3                             1             1             1            1
# 4                             1             1             1            1
# 5                             1             1             1            1
# ...                         ...           ...           ...          ...
# 9041                          1             1             1            1
# 9042                          1             1             1            1
# 9043                          1             1             1            1
# 9044                          1             1             1            1
# 9045                          1             1             1            1
#
# ...
